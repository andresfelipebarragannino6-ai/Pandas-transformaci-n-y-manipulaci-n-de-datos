# %% [markdown]
# <a href="https://colab.research.google.com/github/andresfelipebarragannino6-ai/Pandas-transformaci-n-y-manipulaci-n-de-datos/blob/main/Pandas_Tratamiento_Manipulacion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problema de Negocio**

# %% [markdown]
# Se trata de un algoritmo capaz de analizar las características de una propiedad -como comodidades, tamaño, ocupación del espacio en un período determinado- y sugerir al anfitrión un precio a cobrar por tarifas diarias que garantice ganancias en momentos de alta demanda.

# %% [markdown]
# ## **1. Entendiendo el Problema**

# %%
import pandas as pd

# %%
datos_sin_normalizar = pd.read_json('/content/datos_hosting.json')
datos_sin_normalizar.head()
# Out:
#                                       info_inmuebles
# 0  {'evaluacion_general': '10.0', 'experiencia_lo...
# 1  {'evaluacion_general': '10.0', 'experiencia_lo...
# 2  {'evaluacion_general': '10.0', 'experiencia_lo...
# 3  {'evaluacion_general': '10.0', 'experiencia_lo...
# 4  {'evaluacion_general': '10.0', 'experiencia_lo...

# %%
datos_con_normalizacion = pd.json_normalize(datos_sin_normalizar['info_inmuebles'])
datos_con_normalizacion.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --           10
# 2               10.0                --           11
# 3               10.0                --           12
# 4               10.0                --           14
#
#                                    descripcion_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descripcion_vecindad  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %%
datos_con_normalizacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    70 non-null     object
#  1   experiencia_local     70 non-null     object
#  2   max_hospedes          70 non-null     object
#  3   descripcion_local     70 non-null     object
#  4   descripcion_vecindad  70 non-null     object
#  5   cantidad_baños        70 non-null     object
#  6   cantidad_cuartos      70 non-null     object
#  7   cantidad_camas        70 non-null     object
#  8   modelo_cama           70 non-null     object
#  9   comodidades           70 non-null     object
#  10  cuota_deposito        70 non-null     object
#  11  cuota_limpieza        70 non-null     object
#  12  precio                70 non-null     object
# dtypes: object(13)
# memory usage: 7.2+ KB

# %% [markdown]
# ###**Desafío: trabajando en otros contextos**

# %%
import pandas as pd

# %%
datos_ventas_sin_normalizar = pd.read_json('https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_vendas_clientes.json')
datos_ventas_sin_normalizar.head()
# Out:
#                                         dados_vendas
# 0  {'Data de venda': '06/06/2022', 'Cliente': ['@...
# 1  {'Data de venda': '07/06/2022', 'Cliente': ['I...
# 2  {'Data de venda': '08/06/2022', 'Cliente': ['I...
# 3  {'Data de venda': '09/06/2022', 'Cliente': ['J...
# 4  {'Data de venda': '10/06/2022', 'Cliente': ['M...

# %%
datos_ventas_con_normalizacion = pd.json_normalize(datos_ventas_sin_normalizar['dados_vendas'])
datos_ventas_con_normalizacion.head()
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
datos_ventas_con_normalizacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    5 non-null      object
#  1   Cliente          5 non-null      object
#  2   Valor da compra  5 non-null      object
# dtypes: object(3)
# memory usage: 252.0+ bytes

# %%
datos_condominio_sin_normalizacion = pd.read_json('https://cdn3.gnarususercontent.com.br/2928-transformacao-manipulacao-dados/dados_locacao_imoveis.json')
datos_condominio_sin_normalizacion.head()
# Out:
#                                        dados_locacao
# 0  {'apartamento': 'A101 (blocoAP)', 'datas_combi...
# 1  {'apartamento': 'A102 (blocoAP)', 'datas_combi...
# 2  {'apartamento': 'B201 (blocoAP)', 'datas_combi...
# 3  {'apartamento': 'B202 (blocoAP)', 'datas_combi...
# 4  {'apartamento': 'C301 (blocoAP)', 'datas_combi...

# %%
datos_condominio_con_normalizacion = pd.json_normalize(datos_condominio_sin_normalizacion['dados_locacao'])
datos_condominio_con_normalizacion.head()
# Out:
#       apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0  A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1  A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2  B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3  B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4  C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
#
#                       valor_aluguel
# 0  [$ 1000,0 reais, $ 2500,0 reais]
# 1  [$ 1100,0 reais, $ 2600,0 reais]
# 2  [$ 1200,0 reais, $ 2700,0 reais]
# 3  [$ 1300,0 reais, $ 2800,0 reais]
# 4  [$ 1400,0 reais, $ 2900,0 reais]

# %%
datos_condominio_con_normalizacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 15 non-null     object
#  1   datas_combinadas_pagamento  15 non-null     object
#  2   datas_de_pagamento          15 non-null     object
#  3   valor_aluguel               15 non-null     object
# dtypes: object(4)
# memory usage: 612.0+ bytes

# %% [markdown]
# ## **2. Datos númericos**

# %%
columnas = list(datos_con_normalizacion.columns)
columnas
# Out:
# ['evaluacion_general',
#  'experiencia_local',
#  'max_hospedes',
#  'descripcion_local',
#  'descripcion_vecindad',
#  'cantidad_baños',
#  'cantidad_cuartos',
#  'cantidad_camas',
#  'modelo_cama',
#  'comodidades',
#  'cuota_deposito',
#  'cuota_limpieza',
#  'precio']

# %%
datos_columnas = datos_con_normalizacion.explode(columnas[3:])
datos_columnas
# Out:
#    evaluacion_general experiencia_local max_hospedes  \
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# 0                10.0                --            1
# ..                ...               ...          ...
# 68                nan                --            8
# 68                nan                --            8
# 68                nan                --            8
# 69                nan                --            9
# 69                nan                --            9
#
#                                     descripcion_local  \
# 0   This clean and comfortable one bedroom sits ri...
# 0   Our century old Upper Queen Anne house is loca...
# 0   Cozy room in two-bedroom apartment along the l...
# 0   Very lovely and cozy room for one. Convenientl...
# ...

# %%
datos_columnas.reset_index(inplace = True, drop = True)
datos_columnas.head()
# Out:
#   evaluacion_general experiencia_local max_hospedes  \
# 0               10.0                --            1
# 1               10.0                --            1
# 2               10.0                --            1
# 3               10.0                --            1
# 4               10.0                --            1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...              1
# 1  Upper Queen Anne is a really pleasant, unique ...              1
# 2  The convenience of being in Seattle but on the...              1
# ...

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   object
#  6   cantidad_cuartos      3818 non-null   object
#  7   cantidad_camas        3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
import numpy as np

# %%
datos_columnas['max_hospedes'] = datos_columnas['max_hospedes'].astype(np.int64)

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   object
#  6   cantidad_cuartos      3818 non-null   object
#  7   cantidad_camas        3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 387.9+ KB

# %%
col_numericas = ['cantidad_baños','cantidad_cuartos','cantidad_camas']

# %%
datos_columnas[col_numericas] = datos_columnas[col_numericas].astype(np.int64)

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: int64(4), object(9)
# memory usage: 387.9+ KB

# %%
datos_columnas['evaluacion_general'] = datos_columnas['evaluacion_general'].astype(np.float64)

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
datos_columnas['precio'] = datos_columnas['precio'].apply(lambda x: x.replace('$','').replace(',','').strip())

# %%
datos_columnas.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
datos_columnas['precio'] = datos_columnas['precio'].astype(np.float64)

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   object
#  11  cuota_limpieza        3818 non-null   object
#  12  precio                3818 non-null   float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 387.9+ KB

# %%
import pandas as pd
import numpy as np

# datos de la empresa
datos = {
    'cargo': ['Gerencia', 'Coordinación', 'Supervisión', 'Analista', 'Asistente', 'Operación', 'Asistente', 'Prácticas', 'Asesoría', 'Consultoría'],
    'cantidad': ['2 personas', '1 persona', '3 personas', '4 personas', '5 personas', '3 personas', '2 personas', '1 persona', '1 persona', '1 persona'],
    'salario': ['$10.000 reales', '$8.000 reales', '$7.000 reales', '$5.000 reales', '$4.000 reales', '$3.500 reales', '$3.000 reales', '$1.500 reales', '$2.500 reales', '$6.000 reales']
}

# transformando el diccionario en DataFrame
df = pd.DataFrame(datos)

# df es el DataFrame con los datos de la empres
df
# Out:
#           cargo    cantidad         salario
# 0      Gerencia  2 personas  $10.000 reales
# 1  Coordinación   1 persona   $8.000 reales
# 2   Supervisión  3 personas   $7.000 reales
# 3      Analista  4 personas   $5.000 reales
# 4     Asistente  5 personas   $4.000 reales
# 5     Operación  3 personas   $3.500 reales
# 6     Asistente  2 personas   $3.000 reales
# 7     Prácticas   1 persona   $1.500 reales
# 8      Asesoría   1 persona   $2.500 reales
# 9   Consultoría   1 persona   $6.000 reales

# %%
df['cantidad'] = df['cantidad'].apply(lambda x: x.replace(' personas', '').replace(' persona', ''))
df['salario'] = df['salario'].apply(lambda x: x.replace('$', '').replace(' reales', ''))

# %%
df['cantidad'] = df['cantidad'].astype(np.int64)
df['salario'] = df['salario'].astype(np.float64)

# %%
df
# Out:
#           cargo  cantidad  salario
# 0      Gerencia         2     10.0
# 1  Coordinación         1      8.0
# 2   Supervisión         3      7.0
# 3      Analista         4      5.0
# 4     Asistente         5      4.0
# 5     Operación         3      3.5
# 6     Asistente         2      3.0
# 7     Prácticas         1      1.5
# 8      Asesoría         1      2.5
# 9   Consultoría         1      6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cargo     10 non-null     object
#  1   cantidad  10 non-null     int64
#  2   salario   10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
datos_columnas[['cuota_deposito','cuota_limpieza']] = datos_columnas[['cuota_deposito','cuota_limpieza']].applymap(lambda x: x.replace('$','').replace(',','').strip())
# Out:
# /tmp/ipython-input-4260782235.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   datos_columnas[['cuota_deposito','cuota_limpieza']] = datos_columnas[['cuota_deposito','cuota_limpieza']].applymap(lambda x: x.replace('$','').replace(',','').strip())

# %%
datos_columnas.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
datos_columnas[['cuota_deposito','cuota_limpieza']] = datos_columnas[['cuota_deposito','cuota_limpieza']].astype(np.float64)

# %%
datos_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   evaluacion_general    3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descripcion_local     3818 non-null   object
#  4   descripcion_vecindad  3818 non-null   object
#  5   cantidad_baños        3818 non-null   int64
#  6   cantidad_cuartos      3818 non-null   int64
#  7   cantidad_camas        3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  cuota_deposito        3818 non-null   float64
#  11  cuota_limpieza        3818 non-null   float64
#  12  precio                3818 non-null   float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 387.9+ KB

# %% [markdown]
# ###**Desafío: trabajando en otros contextos**

# %%
datos_ventas_con_normalizacion
# Out:
#   Data de venda                                            Cliente  \
# 0    06/06/2022  [@ANA _LUCIA 321, DieGO ARMANDIU 210, DieGO AR...
# 1    07/06/2022  [Isabely JOanes 738, Isabely JOanes 738, Isabe...
# 2    08/06/2022  [Isabely JOanes 738, JOãO Gabriel 671, Julya m...
# 3    09/06/2022  [Julya meireles 914, MaRIA Julia 444, MaRIA Ju...
# 4    10/06/2022  [MaRIA Julia 444, PEDRO PASCO 812, Paulo castr...
#
#                                 Valor da compra
# 0    [R$ 836,5, R$ 573,33, R$ 392,8, R$ 512,34]
# 1  [R$ 825,31, R$ 168,07, R$ 339,18, R$ 314,69]
# 2  [R$ 682,05, R$ 386,34, R$ 622,65, R$ 630,79]
# 3   [R$ 390,3, R$ 759,16, R$ 334,47, R$ 678,78]
# 4  [R$ 314,24, R$ 311,15, R$ 899,16, R$ 885,24]

# %%
columnas_ventas = list(datos_ventas_con_normalizacion.columns)
columnas_ventas
# Out:
# ['Data de venda', 'Cliente', 'Valor da compra']

# %%
datos_columnas_ventas = datos_ventas_con_normalizacion.explode(columnas_ventas[1:])
datos_columnas_ventas
# Out:
#   Data de venda             Cliente Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 0    06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 0    06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 1    07/06/2022  Isabely JOanes 738       R$ 825,31
# 1    07/06/2022  Isabely JOanes 738       R$ 168,07
# 1    07/06/2022  Isabely JOanes 738       R$ 339,18
# 1    07/06/2022  Isabely JOanes 738       R$ 314,69
# 2    08/06/2022  Isabely JOanes 738       R$ 682,05
# 2    08/06/2022    JOãO Gabriel 671       R$ 386,34
# 2    08/06/2022  Julya meireles 914       R$ 622,65
# 2    08/06/2022  Julya meireles 914       R$ 630,79
# 3    09/06/2022  Julya meireles 914        R$ 390,3
# 3    09/06/2022     MaRIA Julia 444       R$ 759,16
# 3    09/06/2022     MaRIA Julia 444       R$ 334,47
# 3    09/06/2022     MaRIA Julia 444       R$ 678,78
# 4    10/06/2022     MaRIA Julia 444       R$ 314,24
# ...

# %%
datos_columnas_ventas = datos_columnas_ventas.reset_index(drop = True)
datos_columnas_ventas
# Out:
#    Data de venda             Cliente Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321        R$ 836,5
# 1     06/06/2022  DieGO ARMANDIU 210       R$ 573,33
# 2     06/06/2022  DieGO ARMANDIU 210        R$ 392,8
# 3     06/06/2022  DieGO ARMANDIU 210       R$ 512,34
# 4     07/06/2022  Isabely JOanes 738       R$ 825,31
# 5     07/06/2022  Isabely JOanes 738       R$ 168,07
# 6     07/06/2022  Isabely JOanes 738       R$ 339,18
# 7     07/06/2022  Isabely JOanes 738       R$ 314,69
# 8     08/06/2022  Isabely JOanes 738       R$ 682,05
# 9     08/06/2022    JOãO Gabriel 671       R$ 386,34
# 10    08/06/2022  Julya meireles 914       R$ 622,65
# 11    08/06/2022  Julya meireles 914       R$ 630,79
# 12    09/06/2022  Julya meireles 914        R$ 390,3
# 13    09/06/2022     MaRIA Julia 444       R$ 759,16
# 14    09/06/2022     MaRIA Julia 444       R$ 334,47
# 15    09/06/2022     MaRIA Julia 444       R$ 678,78
# 16    10/06/2022     MaRIA Julia 444       R$ 314,24
# ...

# %%
datos_columnas_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     object
# dtypes: object(3)
# memory usage: 612.0+ bytes

# %%
datos_columnas_ventas['Valor da compra'] = datos_columnas_ventas['Valor da compra'].apply(lambda x: x.replace('R$','').replace(',','').strip())

# %%
datos_columnas_ventas
# Out:
#    Data de venda             Cliente Valor da compra
# 0     06/06/2022     @ANA _LUCIA 321            8365
# 1     06/06/2022  DieGO ARMANDIU 210           57333
# 2     06/06/2022  DieGO ARMANDIU 210            3928
# 3     06/06/2022  DieGO ARMANDIU 210           51234
# 4     07/06/2022  Isabely JOanes 738           82531
# 5     07/06/2022  Isabely JOanes 738           16807
# 6     07/06/2022  Isabely JOanes 738           33918
# 7     07/06/2022  Isabely JOanes 738           31469
# 8     08/06/2022  Isabely JOanes 738           68205
# 9     08/06/2022    JOãO Gabriel 671           38634
# 10    08/06/2022  Julya meireles 914           62265
# 11    08/06/2022  Julya meireles 914           63079
# 12    09/06/2022  Julya meireles 914            3903
# 13    09/06/2022     MaRIA Julia 444           75916
# 14    09/06/2022     MaRIA Julia 444           33447
# 15    09/06/2022     MaRIA Julia 444           67878
# 16    10/06/2022     MaRIA Julia 444           31424
# ...

# %%
datos_columnas_ventas['Valor da compra'] = datos_columnas_ventas['Valor da compra'].astype(np.float64)

# %%
datos_columnas_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     object
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 612.0+ bytes

# %%
datos_condominio_con_normalizacion
# Out:
#        apartamento datas_combinadas_pagamento        datas_de_pagamento  \
# 0   A101 (blocoAP)   [01/06/2022, 01/07/2022]  [05/06/2022, 03/07/2022]
# 1   A102 (blocoAP)   [02/06/2022, 02/07/2022]  [02/06/2022, 06/07/2022]
# 2   B201 (blocoAP)   [03/06/2022, 03/07/2022]  [07/06/2022, 03/07/2022]
# 3   B202 (blocoAP)   [04/06/2022, 04/07/2022]  [07/06/2022, 05/07/2022]
# 4   C301 (blocoAP)   [05/06/2022, 05/07/2022]  [10/06/2022, 09/07/2022]
# 5   C302 (blocoAP)   [06/06/2022, 06/07/2022]  [08/06/2022, 12/07/2022]
# 6   D401 (blocoAP)   [07/06/2022, 07/07/2022]  [07/06/2022, 09/07/2022]
# 7   D402 (blocoAP)   [08/06/2022, 08/07/2022]  [10/06/2022, 14/07/2022]
# 8   E501 (blocoAP)   [09/06/2022, 09/07/2022]  [10/06/2022, 09/07/2022]
# 9   E502 (blocoAP)   [10/06/2022, 10/07/2022]  [16/06/2022, 12/07/2022]
# 10  F601 (blocoAP)   [11/06/2022, 11/07/2022]  [17/06/2022, 13/07/2022]
# 11  F602 (blocoAP)   [12/06/2022, 12/07/2022]  [15/06/2022, 12/07/2022]
# ...

# %%
columnas_codominio = list(datos_condominio_con_normalizacion.columns)
columnas_codominio
# Out:
# ['apartamento',
#  'datas_combinadas_pagamento',
#  'datas_de_pagamento',
#  'valor_aluguel']

# %%
datos_columnas_condiominio = datos_condominio_con_normalizacion.explode(columnas_codominio[1:])
datos_columnas_condiominio
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 0   A101 (blocoAP)                 01/07/2022         03/07/2022
# 1   A102 (blocoAP)                 02/06/2022         02/06/2022
# 1   A102 (blocoAP)                 02/07/2022         06/07/2022
# 2   B201 (blocoAP)                 03/06/2022         07/06/2022
# 2   B201 (blocoAP)                 03/07/2022         03/07/2022
# 3   B202 (blocoAP)                 04/06/2022         07/06/2022
# 3   B202 (blocoAP)                 04/07/2022         05/07/2022
# 4   C301 (blocoAP)                 05/06/2022         10/06/2022
# 4   C301 (blocoAP)                 05/07/2022         09/07/2022
# 5   C302 (blocoAP)                 06/06/2022         08/06/2022
# 5   C302 (blocoAP)                 06/07/2022         12/07/2022
# 6   D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %%
datos_columnas_condiominio = datos_columnas_condiominio.reset_index(drop = True)
datos_columnas_condiominio
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento  \
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022
# 11  C302 (blocoAP)                 06/07/2022         12/07/2022
# 12  D401 (blocoAP)                 07/06/2022         07/06/2022
# ...

# %%
datos_columnas_condiominio['valor_aluguel'] = datos_columnas_condiominio['valor_aluguel'].apply(lambda x: x.replace('$','').replace(',','').replace(' reais','').strip())

# %%
datos_columnas_condiominio
# Out:
#        apartamento datas_combinadas_pagamento datas_de_pagamento valor_aluguel
# 0   A101 (blocoAP)                 01/06/2022         05/06/2022         10000
# 1   A101 (blocoAP)                 01/07/2022         03/07/2022         25000
# 2   A102 (blocoAP)                 02/06/2022         02/06/2022         11000
# 3   A102 (blocoAP)                 02/07/2022         06/07/2022         26000
# 4   B201 (blocoAP)                 03/06/2022         07/06/2022         12000
# 5   B201 (blocoAP)                 03/07/2022         03/07/2022         27000
# 6   B202 (blocoAP)                 04/06/2022         07/06/2022         13000
# 7   B202 (blocoAP)                 04/07/2022         05/07/2022         28000
# 8   C301 (blocoAP)                 05/06/2022         10/06/2022         14000
# 9   C301 (blocoAP)                 05/07/2022         09/07/2022         29000
# 10  C302 (blocoAP)                 06/06/2022         08/06/2022         15000
# ...

# %%
datos_columnas_condiominio['valor_aluguel'] = datos_columnas_condiominio['valor_aluguel'].astype(np.float64)

# %%
datos_columnas_condiominio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     object
#  2   datas_de_pagamento          30 non-null     object
#  3   valor_aluguel               30 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ## **3. Datos de texto**

# %%
datos_columnas.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
datos_columnas['descripcion_local'] = datos_columnas['descripcion_local'].str.lower()

# %%
datos_columnas.head()
# Out:
#    evaluacion_general experiencia_local  max_hospedes  \
# 0                10.0                --             1
# 1                10.0                --             1
# 2                10.0                --             1
# 3                10.0                --             1
# 4                10.0                --             1
#
#                                    descripcion_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# 0  Lower Queen Anne is near the Seattle Center (s...               1
# 1  Upper Queen Anne is a really pleasant, unique ...               1
# 2  The convenience of being in Seattle but on the...               1
# ...

# %%
datos_columnas['descripcion_local'][3169]
# Out:
# "built, run and supported by seattle tech and start up veterans, grokhome's focus is to create a supportive environment for smart people working on interesting projects, start ups and more. this listing is an upper bunk, in a 2-person shared room. *note: this fall, there will be major renovations happening on one kitchen and bathroom at a time. there will always be two other working kitchens and two working bathrooms in the house. we'll work to minimize the impact these renovations have on your stay. **this listing is only available to those working in the tech/science space. live in a hacker house, and immerse yourself in the seattle tech scene. you can expect to be surrounded by smart people solving big problems or working on something fun. we have frequent demo nights, and love when our guests share something they are passionate about. if you're new to the city, our deep ties to the seattle tech scene can help you get involved. expand your network, develop your ideas, and learn so
# ...

# %%
datos_columnas['descripcion_local'] = datos_columnas['descripcion_local'].str.replace('[^a-zA-Z0-9\-\']',' ',regex = True) # (^=negación) desde la a hasta la z, como desde la A hasta la Z, como desde 0 hasta 9 y que no incluya (-) ni (') en el reemplazo por nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\-'
# <>:1: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipython-input-1690095428.py:1: SyntaxWarning: invalid escape sequence '\-'
#   datos_columnas['descripcion_local'] = datos_columnas['descripcion_local'].str.replace('[^a-zA-Z0-9\-\']',' ',regex = True) # (^=negación) desde la a hasta la z, como desde la A hasta la Z, como desde 0 hasta 9 y que no incluya (-) ni (') en el reemplazo por nada

# %%
datos_columnas['descripcion_local'] = datos_columnas['descripcion_local'].str.replace('(?<!\w)-(?!\w)','',regex = True) # ((?<!\w)=que no contenga un caracter a la izquierda) y ((?!\w)=que no contenga un caracter a la derecha) esto para el caso de que el quión (-) este en medio de dos palabras si lo esta lo reemplaza con nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2409257597.py:1: SyntaxWarning: invalid escape sequence '\w'
#   datos_columnas['descripcion_local'] = datos_columnas['descripcion_local'].str.replace('(?<!\w)-(?!\w)','',regex = True) # ((?<!\w)=que no contenga un caracter a la izquierda) y ((?!\w)=que no contenga un caracter a la derecha) esto para el caso de que el quión (-) este en medio de dos palabras si lo esta lo reemplaza con nada

# %%
datos_columnas['descripcion_local'].head()
# Out:
# 0    this clean and comfortable one bedroom sits ri...
# 1    our century old upper queen anne house is loca...
# 2    cozy room in two-bedroom apartment along the l...
# 3    very lovely and cozy room for one  convenientl...
# 4    the  studio at mibbett hollow' is in a beautif...
# Name: descripcion_local, dtype: object

# %%
datos_columnas['experiencia_local'] = datos_columnas['descripcion_local'].str.split()
datos_columnas.head()
# Out:
#    evaluacion_general                                  experiencia_local  \
# 0                10.0  [this, clean, and, comfortable, one, bedroom, ...
# 1                10.0  [our, century, old, upper, queen, anne, house,...
# 2                10.0  [cozy, room, in, two-bedroom, apartment, along...
# 3                10.0  [very, lovely, and, cozy, room, for, one, conv...
# 4                10.0  [the, studio, at, mibbett, hollow', is, in, a,...
#
#    max_hospedes                                  descripcion_local  \
# 0             1  this clean and comfortable one bedroom sits ri...
# 1             1  our century old upper queen anne house is loca...
# 2             1  cozy room in two-bedroom apartment along the l...
# 3             1  very lovely and cozy room for one  convenientl...
# 4             1  the  studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# ...

# %%
datos_columnas['comodidades'] = datos_columnas['comodidades'].str.replace('\{|}|\"','',regex = True) # (\{ y \"=busqueda de un caracter especifico), (|}=simbolo de separador, pero ahora quiero que busques el otro caracter en especifico) si lo esta lo reemplaza con nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# /tmp/ipython-input-1017771805.py:1: SyntaxWarning: invalid escape sequence '\{'
#   datos_columnas['comodidades'] = datos_columnas['comodidades'].str.replace('\{|}|\"','',regex = True) # (\{ y \"=busqueda de un caracter especifico), (|}=simbolo de separador, pero ahora quiero que busques el otro caracter en especifico) si lo esta lo reemplaza con nada

# %%
datos_columnas['comodidades'] = datos_columnas['comodidades'].str.split(',')

# %%
datos_columnas.head()
# Out:
#    evaluacion_general                                  experiencia_local  \
# 0                10.0  [this, clean, and, comfortable, one, bedroom, ...
# 1                10.0  [our, century, old, upper, queen, anne, house,...
# 2                10.0  [cozy, room, in, two-bedroom, apartment, along...
# 3                10.0  [very, lovely, and, cozy, room, for, one, conv...
# 4                10.0  [the, studio, at, mibbett, hollow', is, in, a,...
#
#    max_hospedes                                  descripcion_local  \
# 0             1  this clean and comfortable one bedroom sits ri...
# 1             1  our century old upper queen anne house is loca...
# 2             1  cozy room in two-bedroom apartment along the l...
# 3             1  very lovely and cozy room for one  convenientl...
# 4             1  the  studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# ...

# %%
datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.lower()

# %%
datos_columnas.head()
# Out:
#    evaluacion_general                                  experiencia_local  \
# 0                10.0  [this, clean, and, comfortable, one, bedroom, ...
# 1                10.0  [our, century, old, upper, queen, anne, house,...
# 2                10.0  [cozy, room, in, two-bedroom, apartment, along...
# 3                10.0  [very, lovely, and, cozy, room, for, one, conv...
# 4                10.0  [the, studio, at, mibbett, hollow', is, in, a,...
#
#    max_hospedes                                  descripcion_local  \
# 0             1  this clean and comfortable one bedroom sits ri...
# 1             1  our century old upper queen anne house is loca...
# 2             1  cozy room in two-bedroom apartment along the l...
# 3             1  very lovely and cozy room for one  convenientl...
# 4             1  the  studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# ...

# %%
datos_columnas['descripcion_vecindad'][3169]
# Out:
# 'wallingford is a mostly-residential neighborhood, situated between the restaurants, bars and nightlife of fremont or ballard, and the buzzing, academic university district.'

# %%
datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('[^a-zA-Z0-9\-\']',' ',regex = True) # (^=negación) desde la a hasta la z, como desde la A hasta la Z, como desde 0 hasta 9 y que no incluya (-) ni (') en el reemplazo por nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\-'
# <>:1: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipython-input-1985020729.py:1: SyntaxWarning: invalid escape sequence '\-'
#   datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('[^a-zA-Z0-9\-\']',' ',regex = True) # (^=negación) desde la a hasta la z, como desde la A hasta la Z, como desde 0 hasta 9 y que no incluya (-) ni (') en el reemplazo por nada

# %%
datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('(?<!\w)-(?!\w)','',regex = True) # ((?<!\w)=que no contenga un caracter a la izquierda) y ((?!\w)=que no contenga un caracter a la derecha) esto para el caso de que el quión (-) este en medio de dos palabras si lo esta lo reemplaza con nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-3406014738.py:1: SyntaxWarning: invalid escape sequence '\w'
#   datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('(?<!\w)-(?!\w)','',regex = True) # ((?<!\w)=que no contenga un caracter a la izquierda) y ((?!\w)=que no contenga un caracter a la derecha) esto para el caso de que el quión (-) este en medio de dos palabras si lo esta lo reemplaza con nada

# %%
datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('\{|}|\"','',regex = True) # (\{ y \"=busqueda de un caracter especifico), (|}=simbolo de separador, pero ahora quiero que busques el otro caracter en especifico) si lo esta lo reemplaza con nada
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# <>:1: SyntaxWarning: invalid escape sequence '\{'
# /tmp/ipython-input-3001617064.py:1: SyntaxWarning: invalid escape sequence '\{'
#   datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.replace('\{|}|\"','',regex = True) # (\{ y \"=busqueda de un caracter especifico), (|}=simbolo de separador, pero ahora quiero que busques el otro caracter en especifico) si lo esta lo reemplaza con nada

# %%
datos_columnas['descripcion_vecindad'].head()
# Out:
# 0    lower queen anne is near the seattle center  s...
# 1    upper queen anne is a really pleasant  unique ...
# 2    the convenience of being in seattle but on the...
# 3    ballard is lovely  vibrant and one of the most...
# 4
# Name: descripcion_vecindad, dtype: object

# %%
datos_columnas['descripcion_vecindad'] = datos_columnas['descripcion_vecindad'].str.split()

# %%
datos_columnas.head()
# Out:
#    evaluacion_general                                  experiencia_local  \
# 0                10.0  [this, clean, and, comfortable, one, bedroom, ...
# 1                10.0  [our, century, old, upper, queen, anne, house,...
# 2                10.0  [cozy, room, in, two-bedroom, apartment, along...
# 3                10.0  [very, lovely, and, cozy, room, for, one, conv...
# 4                10.0  [the, studio, at, mibbett, hollow', is, in, a,...
#
#    max_hospedes                                  descripcion_local  \
# 0             1  this clean and comfortable one bedroom sits ri...
# 1             1  our century old upper queen anne house is loca...
# 2             1  cozy room in two-bedroom apartment along the l...
# 3             1  very lovely and cozy room for one  convenientl...
# 4             1  the  studio at mibbett hollow' is in a beautif...
#
#                                 descripcion_vecindad  cantidad_baños  \
# ...

# %% [markdown]
# ###**Desafío: trabajando en otros contextos**

# %%
datos_columnas_ventas.head()
# Out:
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022     @ANA _LUCIA 321           8365.0
# 1    06/06/2022  DieGO ARMANDIU 210          57333.0
# 2    06/06/2022  DieGO ARMANDIU 210           3928.0
# 3    06/06/2022  DieGO ARMANDIU 210          51234.0
# 4    07/06/2022  Isabely JOanes 738          82531.0

# %%
datos_columnas_ventas['Cliente'] = datos_columnas_ventas['Cliente'].str.lower()

# %%
datos_columnas_ventas.head()
# Out:
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022     @ana _lucia 321           8365.0
# 1    06/06/2022  diego armandiu 210          57333.0
# 2    06/06/2022  diego armandiu 210           3928.0
# 3    06/06/2022  diego armandiu 210          51234.0
# 4    07/06/2022  isabely joanes 738          82531.0

# %%
datos_columnas_ventas['Cliente'] = datos_columnas_ventas['Cliente'].str.replace('[^a-zA-Z]',' ',regex = True)

# %%
datos_columnas_ventas
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     06/06/2022      ana  lucia               8365.0
# 1     06/06/2022  diego armandiu              57333.0
# 2     06/06/2022  diego armandiu               3928.0
# 3     06/06/2022  diego armandiu              51234.0
# 4     07/06/2022  isabely joanes              82531.0
# 5     07/06/2022  isabely joanes              16807.0
# 6     07/06/2022  isabely joanes              33918.0
# 7     07/06/2022  isabely joanes              31469.0
# 8     08/06/2022  isabely joanes              68205.0
# 9     08/06/2022    jo o gabriel              38634.0
# 10    08/06/2022  julya meireles              62265.0
# 11    08/06/2022  julya meireles              63079.0
# 12    09/06/2022  julya meireles               3903.0
# 13    09/06/2022     maria julia              75916.0
# 14    09/06/2022     maria julia              33447.0
# 15    09/06/2022     maria julia              67878.0
# ...

# %%
datos_columnas_condiominio.head()
# Out:
#       apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0  A101 (blocoAP)                 01/06/2022         05/06/2022        10000.0
# 1  A101 (blocoAP)                 01/07/2022         03/07/2022        25000.0
# 2  A102 (blocoAP)                 02/06/2022         02/06/2022        11000.0
# 3  A102 (blocoAP)                 02/07/2022         06/07/2022        26000.0
# 4  B201 (blocoAP)                 03/06/2022         07/06/2022        12000.0

# %%
datos_columnas_condiominio['apartamento'] = datos_columnas_condiominio['apartamento'].apply(lambda x: x.replace('(blocoAP)','').strip())

# %%
datos_columnas_condiominio
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0         A101                 01/06/2022         05/06/2022        10000.0
# 1         A101                 01/07/2022         03/07/2022        25000.0
# 2         A102                 02/06/2022         02/06/2022        11000.0
# 3         A102                 02/07/2022         06/07/2022        26000.0
# 4         B201                 03/06/2022         07/06/2022        12000.0
# 5         B201                 03/07/2022         03/07/2022        27000.0
# 6         B202                 04/06/2022         07/06/2022        13000.0
# 7         B202                 04/07/2022         05/07/2022        28000.0
# 8         C301                 05/06/2022         10/06/2022        14000.0
# 9         C301                 05/07/2022         09/07/2022        29000.0
# 10        C302                 06/06/2022         08/06/2022        15000.0
# ...

# %%
import datetime

# creando un objeto datetime con la fecha y hora actual
ahora = datetime.datetime.now()

print("Fecha y hora actual:", ahora)
# Out:
# Fecha y hora actual: 2025-12-17 03:22:24.562353

# %%
import datetime
# creando un objeto date con la fecha de hoy
hoy = datetime.date.today()

print("Fecha de hoy:", hoy)
# Out:
# Fecha de hoy: 2025-12-17

# %%
import datetime

# creando dos objetos date con fechas diferentes
data_1 = datetime.date(2022, 1, 1)
data_2 = datetime.date(2023, 1, 1)

# calculando la diferencia entre las dos fechas
diferencia = data_2 - data_1

print("Diferencia entre las dos fechas:", diferencia)
# Out:
# Diferencia entre las dos fechas: 365 days, 0:00:00

# %%
from datetime import datetime, timezone
data_e_hora_atuais = datetime.now()
fuso_horario = timezone.utc
print(fuso_horario)
# Out:
# UTC

# %%
data_e_hora_sao_paulo = data_e_hora_atuais.astimezone(fuso_horario)
data_e_hora_sao_paulo_em_texto = data_e_hora_sao_paulo.strftime('%d/%m/%Y %H:%M')
print(data_e_hora_sao_paulo_em_texto)
# Out:
# 17/12/2025 03:22

# %%
pip install pytz

# %%
from datetime import datetime
from pytz import timezone
data_e_hora_atuais = datetime.now()
fuso_horario = timezone('America/Bogota')
data_e_hora_sao_paulo = data_e_hora_atuais.astimezone(fuso_horario)
data_e_hora_sao_paulo_em_texto = data_e_hora_sao_paulo.strftime('%d/%m/%Y %H:%M')
print(data_e_hora_sao_paulo_em_texto)
# Out:
# 16/12/2025 22:22

# %%
import pytz
for tz in pytz.all_timezones:
    print(tz)
# Out:
# Africa/Abidjan
# Africa/Accra
# Africa/Addis_Ababa
# Africa/Algiers
# Africa/Asmara
# Africa/Asmera
# Africa/Bamako
# Africa/Bangui
# Africa/Banjul
# Africa/Bissau
# Africa/Blantyre
# Africa/Brazzaville
# Africa/Bujumbura
# Africa/Cairo
# Africa/Casablanca
# Africa/Ceuta
# Africa/Conakry
# Africa/Dakar
# Africa/Dar_es_Salaam
# Africa/Djibouti
# Africa/Douala
# Africa/El_Aaiun
# Africa/Freetown
# Africa/Gaborone
# Africa/Harare
# Africa/Johannesburg
# Africa/Juba
# Africa/Kampala
# Africa/Khartoum
# Africa/Kigali
# Africa/Kinshasa
# Africa/Lagos
# Africa/Libreville
# Africa/Lome
# Africa/Luanda
# Africa/Lubumbashi
# Africa/Lusaka
# Africa/Malabo
# Africa/Maputo
# Africa/Maseru
# Africa/Mbabane
# Africa/Mogadishu
# Africa/Monrovia
# Africa/Nairobi
# Africa/Ndjamena
# Africa/Niamey
# Africa/Nouakchott
# Africa/Ouagadougou
# Africa/Porto-Novo
# Africa/Sao_Tome
# Africa/Timbuktu
# Africa/Tripoli
# Africa/Tunis
# Africa/Windhoek
# America/Adak
# America/Anchorage
# America/Anguilla
# ...

# %% [markdown]
# ## **4. Datos de tiempo**

# %%
import pandas as pd

# %%
dt_data = pd.read_json('/content/inmuebles_disponibles.json')
dt_data.head()
# Out:
#     id       fecha  lugar_disponible precio
# 0  857  2016-01-04             False   None
# 1  857  2016-01-05             False   None
# 2  857  2016-01-06             False   None
# 3  857  2016-01-07             False   None
# 4  857  2016-01-08             False   None

# %%
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  object
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), int64(1), object(2)
# memory usage: 11.5+ MB

# %%
dt_data['fecha'] = pd.to_datetime(dt_data['fecha'])

# %%
dt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
import pandas as pd

# Creando el DataFrame con las informaciones
datos = pd.DataFrame({
    'Fecha de venta': ['01/01/2022', '05/02/2022', '10/03/2022', '15/04/2022','18/04/2022','20/04/2022'],
    'valor': [100, 150, 200, 250,80,180]
})

# Mostrando el DataFrame
print(datos)
# Out:
#   Fecha de venta  valor
# 0     01/01/2022    100
# 1     05/02/2022    150
# 2     10/03/2022    200
# 3     15/04/2022    250
# 4     18/04/2022     80
# 5     20/04/2022    180

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha de venta  6 non-null      object
#  1   valor           6 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
datos['Fecha de venta'] = pd.to_datetime(datos['Fecha de venta'], format='%d/%m/%Y')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Fecha de venta  6 non-null      datetime64[ns]
#  1   valor           6 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 228.0 bytes

# %%
dt_data.head()
# Out:
#     id      fecha  lugar_disponible precio
# 0  857 2016-01-04             False   None
# 1  857 2016-01-05             False   None
# 2  857 2016-01-06             False   None
# 3  857 2016-01-07             False   None
# 4  857 2016-01-08             False   None

# %%
dt_data.sample(10)
# Out:
#           id      fecha  lugar_disponible   precio
# 129042   822 2016-07-19              True  $433.00
# 5779    1477 2016-11-03              True   $40.00
# 271175  2572 2016-12-14              True  $117.00
# 119681  2862 2016-11-25             False     None
# 149290   381 2016-01-09              True   $98.00
# 85876    805 2016-04-14              True  $121.00
# 143023   492 2016-11-07              True  $300.00
# 249252  1189 2016-11-21             False     None
# 22719    509 2016-04-02              True  $144.00
# 210657  3323 2016-02-25              True  $141.00

# %%
dt_data['fecha'].dt.strftime('%Y-%m')
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 364995    2016-12
# 364996    2016-12
# 364997    2016-12
# 364998    2017-01
# 364999    2017-01
# Name: fecha, Length: 365000, dtype: object

# %%
subset = dt_data.groupby(dt_data['fecha'].dt.strftime('%Y-%m'))['lugar_disponible'].sum()
subset
# Out:
# fecha
# 2016-01    16543
# 2016-02    20128
# 2016-03    23357
# 2016-04    22597
# 2016-05    23842
# 2016-06    23651
# 2016-07    22329
# 2016-08    22529
# 2016-09    22471
# 2016-10    23765
# 2016-11    23352
# 2016-12    24409
# 2017-01     1574
# Name: lugar_disponible, dtype: int64

# %%
dt_data.head()
# Out:
#     id      fecha  lugar_disponible precio
# 0  857 2016-01-04             False   None
# 1  857 2016-01-05             False   None
# 2  857 2016-01-06             False   None
# 3  857 2016-01-07             False   None
# 4  857 2016-01-08             False   None

# %%
columnas_2 = list(dt_data.columns)
columnas_2
# Out:
# ['id', 'fecha', 'lugar_disponible', 'precio']

# %%
datos_columnas_2 = dt_data.explode(columnas_2[3:])
datos_columnas_2
# Out:
#           id      fecha  lugar_disponible   precio
# 0        857 2016-01-04             False     None
# 1        857 2016-01-05             False     None
# 2        857 2016-01-06             False     None
# 3        857 2016-01-07             False     None
# 4        857 2016-01-08             False     None
# ...      ...        ...               ...      ...
# 364995  3279 2016-12-29              True  $140.00
# 364996  3279 2016-12-30              True  $140.00
# 364997  3279 2016-12-31              True  $140.00
# 364998  3279 2017-01-01              True  $140.00
# 364999  3279 2017-01-02             False     None
#
# [365000 rows x 4 columns]

# %%
datos_columnas_2.reset_index(inplace = True, drop = True)
datos_columnas_2.head()
# Out:
#     id      fecha  lugar_disponible precio
# 0  857 2016-01-04             False   None
# 1  857 2016-01-05             False   None
# 2  857 2016-01-06             False   None
# 3  857 2016-01-07             False   None
# 4  857 2016-01-08             False   None

# %%
datos_columnas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ MB

# %%
import numpy as np
datos_columnas_2['precio'] = datos_columnas_2['precio'].apply(lambda x: x.replace('$','').replace(',','').strip() if pd.notna(x) else np.nan)

# %%
datos_columnas_2.sample(5)
# Out:
#           id      fecha  lugar_disponible  precio
# 202865  1307 2016-10-20              True   97.00
# 283026  1289 2016-06-03             False     NaN
# 337754  2523 2016-05-12             False     NaN
# 53739   1024 2016-03-28              True  160.00
# 271303  2195 2016-04-21             False     NaN

# %%
datos_columnas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ MB

# %%
datos_columnas_2['precio'] = datos_columnas_2['precio'].fillna('0.0')

# %%
datos_columnas_2.head()
# Out:
#     id      fecha  lugar_disponible precio
# 0  857 2016-01-04             False    0.0
# 1  857 2016-01-05             False    0.0
# 2  857 2016-01-06             False    0.0
# 3  857 2016-01-07             False    0.0
# 4  857 2016-01-08             False    0.0

# %%
datos_columnas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            365000 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 8.7+ MB

# %%
datos_columnas_2['precio'] = datos_columnas_2['precio'].astype(np.float64)

# %%
datos_columnas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                365000 non-null  int64
#  1   fecha             365000 non-null  datetime64[ns]
#  2   lugar_disponible  365000 non-null  bool
#  3   precio            365000 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 8.7 MB

# %% [markdown]
# ###**Desafío: trabajando en otros contextos**

# %%
datos_columnas_ventas.head()
# Out:
#   Data de venda             Cliente  Valor da compra
# 0    06/06/2022      ana  lucia               8365.0
# 1    06/06/2022  diego armandiu              57333.0
# 2    06/06/2022  diego armandiu               3928.0
# 3    06/06/2022  diego armandiu              51234.0
# 4    07/06/2022  isabely joanes              82531.0

# %%
datos_columnas_ventas['Data de venda'] = pd.to_datetime(datos_columnas_ventas['Data de venda'],format = '%d/%m/%Y')

# %%
datos_columnas_ventas
# Out:
#    Data de venda             Cliente  Valor da compra
# 0     2022-06-06      ana  lucia               8365.0
# 1     2022-06-06  diego armandiu              57333.0
# 2     2022-06-06  diego armandiu               3928.0
# 3     2022-06-06  diego armandiu              51234.0
# 4     2022-06-07  isabely joanes              82531.0
# 5     2022-06-07  isabely joanes              16807.0
# 6     2022-06-07  isabely joanes              33918.0
# 7     2022-06-07  isabely joanes              31469.0
# 8     2022-06-08  isabely joanes              68205.0
# 9     2022-06-08    jo o gabriel              38634.0
# 10    2022-06-08  julya meireles              62265.0
# 11    2022-06-08  julya meireles              63079.0
# 12    2022-06-09  julya meireles               3903.0
# 13    2022-06-09     maria julia              75916.0
# 14    2022-06-09     maria julia              33447.0
# 15    2022-06-09     maria julia              67878.0
# ...

# %%
datos_columnas_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data de venda    20 non-null     datetime64[ns]
#  1   Cliente          20 non-null     object
#  2   Valor da compra  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 612.0+ bytes

# %%
total_de_compras_clientes = datos_columnas_ventas.groupby(['Cliente'])['Valor da compra'].sum()

# %%
total_de_compras_clientes
# Out:
# Cliente
#  ana  lucia             8365.0
# diego armandiu        112495.0
# isabely joanes        232930.0
# jo o gabriel           38634.0
# julya meireles        129247.0
# maria julia           208665.0
# paulo castro           89916.0
# pedro pasco            31115.0
# thiago fritzz          88524.0
# Name: Valor da compra, dtype: float64

# %%
datos_columnas_condiominio.head()
# Out:
#   apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0        A101                 01/06/2022         05/06/2022        10000.0
# 1        A101                 01/07/2022         03/07/2022        25000.0
# 2        A102                 02/06/2022         02/06/2022        11000.0
# 3        A102                 02/07/2022         06/07/2022        26000.0
# 4        B201                 03/06/2022         07/06/2022        12000.0

# %%
datos_columnas_condiominio['datas_combinadas_pagamento'] = pd.to_datetime(datos_columnas_condiominio['datas_combinadas_pagamento'],format = '%d/%m/%Y')

# %%
datos_columnas_condiominio['datas_de_pagamento'] = pd.to_datetime(datos_columnas_condiominio['datas_de_pagamento'],format = '%d/%m/%Y')

# %%
datos_columnas_condiominio
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel
# 0         A101                 2022-06-01         2022-06-05        10000.0
# 1         A101                 2022-07-01         2022-07-03        25000.0
# 2         A102                 2022-06-02         2022-06-02        11000.0
# 3         A102                 2022-07-02         2022-07-06        26000.0
# 4         B201                 2022-06-03         2022-06-07        12000.0
# 5         B201                 2022-07-03         2022-07-03        27000.0
# 6         B202                 2022-06-04         2022-06-07        13000.0
# 7         B202                 2022-07-04         2022-07-05        28000.0
# 8         C301                 2022-06-05         2022-06-10        14000.0
# 9         C301                 2022-07-05         2022-07-09        29000.0
# 10        C302                 2022-06-06         2022-06-08        15000.0
# ...

# %%
datos_columnas_condiominio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   apartamento                 30 non-null     object
#  1   datas_combinadas_pagamento  30 non-null     datetime64[ns]
#  2   datas_de_pagamento          30 non-null     datetime64[ns]
#  3   valor_aluguel               30 non-null     float64
# dtypes: datetime64[ns](2), float64(1), object(1)
# memory usage: 1.1+ KB

# %%
datos_columnas_condiominio['diferencia de días'] = (datos_columnas_condiominio['datas_de_pagamento'] - datos_columnas_condiominio['datas_combinadas_pagamento']).dt.days

# %%
datos_columnas_condiominio
# Out:
#    apartamento datas_combinadas_pagamento datas_de_pagamento  valor_aluguel  \
# 0         A101                 2022-06-01         2022-06-05        10000.0
# 1         A101                 2022-07-01         2022-07-03        25000.0
# 2         A102                 2022-06-02         2022-06-02        11000.0
# 3         A102                 2022-07-02         2022-07-06        26000.0
# 4         B201                 2022-06-03         2022-06-07        12000.0
# 5         B201                 2022-07-03         2022-07-03        27000.0
# 6         B202                 2022-06-04         2022-06-07        13000.0
# 7         B202                 2022-07-04         2022-07-05        28000.0
# 8         C301                 2022-06-05         2022-06-10        14000.0
# 9         C301                 2022-07-05         2022-07-09        29000.0
# 10        C302                 2022-06-06         2022-06-08        15000.0
# ...

# %%
media_diferencias_dias = datos_columnas_condiominio.groupby(['apartamento'])['diferencia de días'].mean()

# %%
media_diferencias_dias
# Out:
# apartamento
# A101    3.0
# A102    2.0
# B201    2.0
# B202    2.0
# C301    4.5
# C302    4.0
# D401    1.0
# D402    4.0
# E501    0.5
# E502    4.0
# F601    4.0
# F602    1.5
# G701    6.5
# G702    2.0
# H801    2.0
# Name: diferencia de días, dtype: float64
